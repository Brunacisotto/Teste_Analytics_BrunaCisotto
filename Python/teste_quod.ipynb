# %%
import pandas as pd
import numpy as np

# %%
# numero de registros (escolhi fazer com 1000 para gerar uma massa de dados significativa)
numreg = 1000

# %%
# criar ids a partir de 1 e somar sempre +1
id = range(1, numreg+1)

# %%
# gerando datas aleatorias entre 01/01/2023 e 31/12/2023
data = pd.to_datetime(
    np.random.choice(pd.date_range("2023-01-01", "2023-12-31"), numreg)
)

# %%
# gerar produto e categoria
produto = ["Relogio Inteligente", "Monitor Cardiaco", "Camiseta", "Calca", "Tenis",
            "Bicicleta", "Mini Trampolim", "Barrinha de Cereal", "Livro de Receitas Fitnes", "Mochila", "Luvas","Barraca de Camping","Cantil","Meias", "Multi-vitaminico", "Creatina"]

categoria = {
    "Relogio Inteligente": "Eletronicos",
    "Monitor Cardiaco": "Eletronicos",
    "Camiseta": "Vestuario",
    "Calca": "Vestuario",
    "Tenis": "Vestuario",
    "Bicicleta": "Equipamento Esportivo",
    "Mini Trampolim": "Equipamento Esportivo",
    "Barrinha de Cereal": "Alimentos",
    "Livro de Receitas Fitnes": "Educacao",
    "Mochila": "Acessorios",
    "Luvas": "Acessorios",
    "Barraca de Camping": "Lazer",
    "Cantil": "Acessorios",
    "Meias": "Vestuario",
    "Multi-vitaminico": "Suplemento",
    "Creatina": "Suplemento"

}

preco = {
    "Relogio Inteligente": 899.90,
    "Monitor Cardiaco": 353.00,
    "Camiseta": 79.90,
    "Calca": 246.00,
    "Tenis": 299.99,
    "Bicicleta": 2450.00,
    "Mini Trampolim": 350.00,
    "Barrinha de Cereal": 4.50,
    "Livro de Receitas Fitnes": 65.00,
    "Mochila": 120.00,
    "Luvas": 97.00,
    "Barraca de Camping": 680.00,
    "Cantil": 35.00,
    "Meias": 19.90,
    "Multi-vitaminico": 89.90,
    "Creatina": 139.90
}

# %%
# produtos aleatorios
prodaleatorio = np.random.choice(produto, numreg)

# %%
# categoria/produto
cat = [categoria[p] for p in prodaleatorio]

# %%
# quantidade entre 1 e 50
quant = np.random.randint(1, 51, numreg)

# %%
# preço/produto
precos = [preco[p] for p in prodaleatorio]

# %%
# gerar base de dados
basebruta = pd.DataFrame({
    "ID": id,
    "Data": data,
    "Produto": prodaleatorio,
    "Categoria": cat,
    "Quantidade": quant,
    "Preco": precos
})

# %%
basebruta.head(20)
# Out:
#     ID       Data             Produto              Categoria  Quantidade  \
# 0    1 2023-01-31    Monitor Cardiaco            Eletronicos          28
# 1    2 2023-07-07             Mochila             Acessorios          34
# 2    3 2023-06-21           Bicicleta  Equipamento Esportivo          45
# 3    4 2023-01-31             Mochila             Acessorios          25
# 4    5 2023-05-15              Cantil             Acessorios          38
# 5    6 2023-10-12    Multi-vitaminico             Suplemento          39
# 6    7 2023-09-12               Calca              Vestuario          41
# 7    8 2023-02-28            Creatina             Suplemento          25
# 8    9 2023-10-22    Monitor Cardiaco            Eletronicos          12
# 9   10 2023-03-23            Camiseta              Vestuario          50
# 10  11 2023-02-23               Tenis              Vestuario          42
# 11  12 2023-06-29              Cantil             Acessorios           9
# 12  13 2023-10-06               Calca              Vestuario          12
# 13  14 2023-01-16           Bicicleta  Equipamento Esportivo          34
# 14  15 2023-02-20  Barraca de Camping                  Lazer           3
# 15  16 2023-04-27               Calca              Vestuario          12
# 16  17 2023-04-18               Meias              Vestuario          25
# 17  18 2023-01-20  Barraca de Camping                  Lazer          50
# 18  19 2023-12-07               Luvas             Acessorios          45
# 19  20 2023-12-03             Mochila             Acessorios           5
#
#       Preco
# 0    353.00
# 1    120.00
# 2   2450.00
# 3    120.00
# 4     35.00
# 5     89.90
# 6    246.00
# 7    139.90
# 8    353.00
# 9     79.90
# 10   299.99
# 11    35.00
# 12   246.00
# 13  2450.00
# 14   680.00
# 15   246.00
# 16    19.90
# 17   680.00
# 18    97.00
# 19   120.00

# %%
basebruta.to_csv("data1.csv", index=False)

# %%
#gerar alguns valores nulos em preço e produto (aleatorios)
basebruta.loc[np.random.choice(basebruta.index, 5, replace=False), "Preco"] = np.nan
basebruta.loc[np.random.choice(basebruta.index, 3, replace=False), "Produto"] = np.nan

# %%
#gerar 10 linhas duplicadas (aleatorias)
basebruta = pd.concat([basebruta, basebruta.sample(10)], ignore_index=True)

# %%
#salvar dataset
basebruta.to_csv("dataasertratado.csv", index=False)

# %%
#consultar linhas duplicadas
duplicadas = basebruta[basebruta.duplicated()]
print(duplicadas)
# Out:
#        ID       Data                   Produto   Categoria  Quantidade   Preco
# 1000  682 2023-03-15          Multi-vitaminico  Suplemento          35   89.90
# 1001  943 2023-11-23  Livro de Receitas Fitnes    Educacao          41   65.00
# 1002  122 2023-02-25                     Tenis   Vestuario          23  299.99
# 1003   85 2023-08-22  Livro de Receitas Fitnes    Educacao          26   65.00
# 1004  784 2023-01-03                     Meias   Vestuario          40   19.90
# 1005   47 2023-01-21                     Luvas  Acessorios          42   97.00
# 1006  540 2023-01-11        Barrinha de Cereal   Alimentos          12    4.50
# 1007  675 2023-03-14                   Mochila  Acessorios          48  120.00
# 1008  442 2023-12-20                     Meias   Vestuario          38   19.90
# 1009  592 2023-06-17                     Luvas  Acessorios          17   97.00

# %%
#apagando duplicadas
basebruta.drop_duplicates(inplace=True)

# %%
#verificando se foram apagadas
duplicadas = basebruta[basebruta.duplicated()]
print(duplicadas)
# Out:
# Empty DataFrame
# Columns: [ID, Data, Produto, Categoria, Quantidade, Preco]
# Index: []

# %%
#achando linhas com valores nulos
linhasnulos = basebruta[basebruta.isna().any(axis=1)]
print(linhasnulos)
# Out:
#       ID       Data             Produto              Categoria  Quantidade  \
# 511  512 2023-07-20                 NaN             Acessorios          35
# 580  581 2023-02-02  Barraca de Camping                  Lazer          42
# 634  635 2023-05-18             Mochila             Acessorios          40
# 648  649 2023-09-16            Camiseta              Vestuario          46
# 816  817 2023-12-12                 NaN              Vestuario          11
# 890  891 2023-08-27              Cantil             Acessorios          12
# 918  919 2023-02-22      Mini Trampolim  Equipamento Esportivo          26
# 945  946 2023-11-14                 NaN             Suplemento           7
#
#       Preco
# 511  120.00
# 580     NaN
# 634     NaN
# 648     NaN
# 816  299.99
# 890     NaN
# 918     NaN
# 945  139.90

# %%
# tratando nulos
basebruta.dropna(inplace=True)

# %%
#verificando se foram apagados
linhasnulos = basebruta[basebruta.isna().any(axis=1)]
print(linhasnulos)
# Out:
# Empty DataFrame
# Columns: [ID, Data, Produto, Categoria, Quantidade, Preco]
# Index: []

# %%
#veririfcando a quantidade de linhas restantes após tratramentos
print(len(basebruta))
# Out:
# 992

# %%
#conferindo tipos do dados
basebruta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 992 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          992 non-null    int64
#  1   Data        992 non-null    datetime64[ns]
#  2   Produto     992 non-null    object
#  3   Categoria   992 non-null    object
#  4   Quantidade  992 non-null    int64
#  5   Preco       992 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 54.2+ KB

# %%
#salvar dataset limpo
basebruta.to_csv("data_clean.csv", index=False)

# %%
#abrir dataset limpo
baselimpa = pd.read_csv('data_clean.csv')

# %%
baselimpa.head(20)
# Out:
#     ID        Data             Produto              Categoria  Quantidade  \
# 0    1  2023-01-31    Monitor Cardiaco            Eletronicos          28
# 1    2  2023-07-07             Mochila             Acessorios          34
# 2    3  2023-06-21           Bicicleta  Equipamento Esportivo          45
# 3    4  2023-01-31             Mochila             Acessorios          25
# 4    5  2023-05-15              Cantil             Acessorios          38
# 5    6  2023-10-12    Multi-vitaminico             Suplemento          39
# 6    7  2023-09-12               Calca              Vestuario          41
# 7    8  2023-02-28            Creatina             Suplemento          25
# 8    9  2023-10-22    Monitor Cardiaco            Eletronicos          12
# 9   10  2023-03-23            Camiseta              Vestuario          50
# 10  11  2023-02-23               Tenis              Vestuario          42
# 11  12  2023-06-29              Cantil             Acessorios           9
# 12  13  2023-10-06               Calca              Vestuario          12
# 13  14  2023-01-16           Bicicleta  Equipamento Esportivo          34
# 14  15  2023-02-20  Barraca de Camping                  Lazer           3
# 15  16  2023-04-27               Calca              Vestuario          12
# 16  17  2023-04-18               Meias              Vestuario          25
# 17  18  2023-01-20  Barraca de Camping                  Lazer          50
# 18  19  2023-12-07               Luvas             Acessorios          45
# 19  20  2023-12-03             Mochila             Acessorios           5
#
#       Preco
# 0    353.00
# 1    120.00
# 2   2450.00
# 3    120.00
# 4     35.00
# 5     89.90
# 6    246.00
# 7    139.90
# 8    353.00
# 9     79.90
# 10   299.99
# 11    35.00
# 12   246.00
# 13  2450.00
# 14   680.00
# 15   246.00
# 16    19.90
# 17   680.00
# 18    97.00
# 19   120.00

# %%
# criando coluna total de vendas
baselimpa['Total de Vendas'] = baselimpa['Quantidade'] * baselimpa['Preco']

# %%
baselimpa.head(20)
# Out:
#     ID        Data             Produto              Categoria  Quantidade  \
# 0    1  2023-01-31    Monitor Cardiaco            Eletronicos          28
# 1    2  2023-07-07             Mochila             Acessorios          34
# 2    3  2023-06-21           Bicicleta  Equipamento Esportivo          45
# 3    4  2023-01-31             Mochila             Acessorios          25
# 4    5  2023-05-15              Cantil             Acessorios          38
# 5    6  2023-10-12    Multi-vitaminico             Suplemento          39
# 6    7  2023-09-12               Calca              Vestuario          41
# 7    8  2023-02-28            Creatina             Suplemento          25
# 8    9  2023-10-22    Monitor Cardiaco            Eletronicos          12
# 9   10  2023-03-23            Camiseta              Vestuario          50
# 10  11  2023-02-23               Tenis              Vestuario          42
# 11  12  2023-06-29              Cantil             Acessorios           9
# 12  13  2023-10-06               Calca              Vestuario          12
# 13  14  2023-01-16           Bicicleta  Equipamento Esportivo          34
# 14  15  2023-02-20  Barraca de Camping                  Lazer           3
# 15  16  2023-04-27               Calca              Vestuario          12
# 16  17  2023-04-18               Meias              Vestuario          25
# 17  18  2023-01-20  Barraca de Camping                  Lazer          50
# 18  19  2023-12-07               Luvas             Acessorios          45
# 19  20  2023-12-03             Mochila             Acessorios           5
#
#       Preco  Total de Vendas
# 0    353.00          9884.00
# 1    120.00          4080.00
# 2   2450.00        110250.00
# 3    120.00          3000.00
# 4     35.00          1330.00
# 5     89.90          3506.10
# 6    246.00         10086.00
# 7    139.90          3497.50
# 8    353.00          4236.00
# 9     79.90          3995.00
# 10   299.99         12599.58
# 11    35.00           315.00
# 12   246.00          2952.00
# 13  2450.00         83300.00
# 14   680.00          2040.00
# 15   246.00          2952.00
# 16    19.90           497.50
# 17   680.00         34000.00
# 18    97.00          4365.00
# 19   120.00           600.00

# %%
#salvando base com a coluna total de vendas
baselimpa.to_csv("data_clean_comtotaldevendas.csv", index=False)

# %%
#agrupando os produtos e somando o valor total de vendas de cada um
vendastotais = baselimpa.groupby('Produto')['Total de Vendas'].sum().reset_index()
print(vendastotais)
# Out:
#                      Produto  Total de Vendas
# 0         Barraca de Camping       1126080.00
# 1         Barrinha de Cereal          5593.50
# 2                  Bicicleta       3596600.00
# 3                      Calca        394092.00
# 4                   Camiseta        134311.90
# 5                     Cantil         64680.00
# 6                   Creatina        219922.80
# 7   Livro de Receitas Fitnes        139945.00
# 8                      Luvas        183912.00
# 9                      Meias         29710.70
# 10            Mini Trampolim        554050.00
# 11                   Mochila        177960.00
# 12          Monitor Cardiaco        538325.00
# 13          Multi-vitaminico        148245.10
# 14       Relogio Inteligente       1233762.90
# 15                     Tenis        491383.62

# %%
#ordenando total de vendas em ordem descrescente
vendastotais_ordenado = vendastotais.sort_values(by='Total de Vendas',ascending=False)
print("Produtos com maior Valor Total de Venda em ordem Descrescente")
print(vendastotais_ordenado)
# Out:
# Produtos com maior Valor Total de Venda em ordem Descrescente
#                      Produto  Total de Vendas
# 2                  Bicicleta       3596600.00
# 14       Relogio Inteligente       1233762.90
# 0         Barraca de Camping       1126080.00
# 10            Mini Trampolim        554050.00
# 12          Monitor Cardiaco        538325.00
# 15                     Tenis        491383.62
# 3                      Calca        394092.00
# 6                   Creatina        219922.80
# 8                      Luvas        183912.00
# 11                   Mochila        177960.00
# 13          Multi-vitaminico        148245.10
# 7   Livro de Receitas Fitnes        139945.00
# 4                   Camiseta        134311.90
# 5                     Cantil         64680.00
# 9                      Meias         29710.70
# 1         Barrinha de Cereal          5593.50

# %%
# selecionar a primeira linha, que é o produto com maior valor total de vandas
vendastotais_ordenado = vendastotais.sort_values(by='Total de Vendas', ascending=False)
maiorvenda = vendastotais_ordenado.iloc[0]

print("Produto com a Maior Quantidade de Vendas:")
print(maiorvenda)
# Out:
# Produto com a Maior Quantidade de Vendas:
# Produto            Bicicleta
# Total de Vendas    3596600.0
# Name: 2, dtype: object

# %%
#agrupando os produtos e somando a quantidade total de unidades vendidas
unidadestotais = baselimpa.groupby('Produto')['Quantidade'].sum().reset_index()

# %%
#ordenando total de unidades vendidas em ordem descrescente
unidadestotais_ordenado = unidadestotais.sort_values(by='Quantidade',ascending=False)
print("Produtos com maior quantidades unitaria de vendas em ordem Descrescente")
print(unidadestotais_ordenado)
# Out:
# Produtos com maior quantidades unitaria de vendas em ordem Descrescente
#                      Produto  Quantidade
# 7   Livro de Receitas Fitnes        2153
# 8                      Luvas        1896
# 5                     Cantil        1848
# 4                   Camiseta        1681
# 0         Barraca de Camping        1656
# 13          Multi-vitaminico        1649
# 15                     Tenis        1638
# 3                      Calca        1602
# 10            Mini Trampolim        1583
# 6                   Creatina        1572
# 12          Monitor Cardiaco        1525
# 9                      Meias        1493
# 11                   Mochila        1483
# 2                  Bicicleta        1468
# 14       Relogio Inteligente        1371
# 1         Barrinha de Cereal        1243

# %%
# selecionar a primeira linha, que é o produto com maior quantidade unitaria de vendas
unidadestotais_ordenado = unidadestotais.sort_values(by='Quantidade', ascending=False)
maiorquantidade = unidadestotais_ordenado.iloc[0]

print("Produto com a Maior Quantidade de Unidades Vendidas:")
print(maiorquantidade)
# Out:
# Produto com a Maior Quantidade de Unidades Vendidas:
# Produto       Livro de Receitas Fitnes
# Quantidade                        2153
# Name: 7, dtype: object
